# %%
import yfinance as yf
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = yf.download( "VALE KGC PXI BMY TEVA", start="2014-01-01", end="2019-01-01")
data.fillna(method='bfill', inplace=True)
# Out:
# [*********************100%***********************]  5 of 5 downloaded

# %%
pylab.rcParams['figure.figsize'] = (15, 9)   
print(data["Adj Close"].head())
data["Adj Close"].plot(grid = True, figsize=(15, 9))
# Out:
#               BMY   KGC    PXI   TEVA   VALE
# Date
# 2013-12-31  45.47  4.38  51.80  35.89  12.72
# 2014-01-02  44.72  4.48  51.19  36.05  12.11
# 2014-01-03  45.21  4.51  50.98  35.71  11.95
# 2014-01-06  45.03  4.60  51.00  36.26  11.91
# 2014-01-07  44.97  4.59  51.01  36.90  11.71
